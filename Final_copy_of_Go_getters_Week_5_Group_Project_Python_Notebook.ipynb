# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciiku-Kihara/SANITATION-IMPROVEMENT-PROJECT/blob/main/Final_copy_of_Go_getters_Week_5_Group_Project_Python_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.0.LOADING DATASET**

# %%
#import the Numpy library
 
import pandas as pd
 
#import pandas library
 
import numpy as np

# %%
#Loading dataset 
#preview first five entries to ensure the table has been loaded correctly
#
sanitation_by_district = pd.read_csv('sanitation_by_district.csv')

sanitation_by_district.head(5)
# Out:
#           _District Rural/Urban  ...                     Location OBJECTID
# 0           MOMBASA       Rural  ...           (-3.9685, 39.6977)        0
# 1            CHALBI       Urban  ...   (3.399917155, 37.36288736)        1
# 2        KURIA EAST       Urban  ...  (-1.279753411, 34.65699509)        2
# 3             MANGA       Rural  ...  (-0.688310175, 34.90211779)        3
# 4  TRANS NZOIA EAST       Urban  ...   (1.022635873, 35.18029104)        4
#
# [5 rows x 28 columns]

# %%
#Preview info on dataset
#
sanitation_by_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 28 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   _District                                            316 non-null    object
#  1   Rural/Urban                                          316 non-null    object
#  2   %_of_households_with_Main_Sewer                      290 non-null    object
#  3   %_of_households_with_Septic_Tank                     290 non-null    object
#  4   %_of_households_with_Cess_Pool                       290 non-null    object
#  5   %_of_households_with_VIP_Pit_Latrine                 290 non-null    object
#  6   %_of_households_with_Pit_Latrine_Covered/Uncovered   290 non-null    object
#  7   %_of_households_with_Bucket                          290 non-null    object
#  8   %_of_households_with_Bush                            290 non-null    object
#  9   %_of_households_with_Other                           290 non-null    object
#  10  Households                                           316 non-null    int64
#  11  No_of_households_with_Main_Sewer                     316 non-null    int64
#  12  No_of_households_with_Septic_Tank                    316 non-null    int64
#  13  No_of_households_with_Cess_Pool                      316 non-null    int64
#  14  No_of_households_with_VIP_Pit_Latrine                316 non-null    int64
#  15  No_of_households_with_Pit_Latrine_Covered/Uncovered  316 non-null    int64
#  16  No_of_households_with_Bucket                         316 non-null    int64
#  17  No_of_households_with_Bush                           316 non-null    int64
#  18  No_of_households_with_Other                          316 non-null    int64
#  19  Province                                             316 non-null    object
#  20  County                                               316 non-null    object
#  21  Census_Table                                         316 non-null    object
#  22  MTEF                                                 316 non-null    object
#  23  MTP                                                  316 non-null    object
#  24  Longtitude                                           316 non-null    float64
#  25  Latitude                                             316 non-null    float64
#  26  Location                                             316 non-null    object
#  27  OBJECTID                                             316 non-null    int64
# dtypes: float64(2), int64(10), object(16)
# memory usage: 69.2+ KB

# %%
#View the columns in our dataset
#
sanitation_by_district.columns
# Out:
# Index(['_District', 'Rural/Urban', '%_of_households_with_Main_Sewer',
#        '%_of_households_with_Septic_Tank', '%_of_households_with_Cess_Pool',
#        '%_of_households_with_VIP_Pit_Latrine',
#        '%_of_households_with_Pit_Latrine_Covered/Uncovered',
#        '%_of_households_with_Bucket', '%_of_households_with_Bush',
#        '%_of_households_with_Other', 'Households',
#        'No_of_households_with_Main_Sewer', 'No_of_households_with_Septic_Tank',
#        'No_of_households_with_Cess_Pool',
#        'No_of_households_with_VIP_Pit_Latrine',
#        'No_of_households_with_Pit_Latrine_Covered/Uncovered',
#        'No_of_households_with_Bucket', 'No_of_households_with_Bush',
#        'No_of_households_with_Other', 'Province', 'County', 'Census_Table',
#        'MTEF', 'MTP', 'Longtitude', 'Latitude', 'Location', 'OBJECTID'],
#       dtype='object')

# %%
#View the dimensions of dataset
#i.e how many columns and rows are in our dataset
#
sanitation_by_district.shape
# Out:
# (316, 28)

# %%
#Preview general statistics about data
#
sanitation_by_district.describe()
# Out:
#           Households  No_of_households_with_Main_Sewer  ...    Latitude    OBJECTID
# count     316.000000                        316.000000  ...  316.000000  316.000000
# mean    27746.689873                       2134.623418  ...   -0.259561  157.500000
# std     37068.244631                      16223.390276  ...    1.543394   91.365566
# min         0.000000                          0.000000  ...   -4.397199    0.000000
# 25%      6043.250000                          5.750000  ...   -1.060809   78.750000
# 50%     19699.500000                         37.000000  ...   -0.208739  157.500000
# 75%     36117.500000                        145.250000  ...    0.489045  236.250000
# max    369866.000000                     214428.000000  ...    4.313788  315.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# **2.0.DATA PREPARATION.**

# %% [markdown]
# **2.1.Data Cleaning.**

# %% [markdown]
# Validity of data

# %%
#Dropping irrelevant columns 
#
sanitation_by_district.drop(['MTEF', 'MTP', 'Longtitude', 'Latitude', 'Location', 'OBJECTID','Census_Table'], axis = 1, inplace = True)

sanitation_by_district.head(5)
# Out:
#           _District Rural/Urban  ...     Province       County
# 0           MOMBASA       Rural  ...        COAST      Mombasa
# 1            CHALBI       Urban  ...      EASTERN     Marsabit
# 2        KURIA EAST       Urban  ...       NYANZA       Migori
# 3             MANGA       Rural  ...       NYANZA      Nyamira
# 4  TRANS NZOIA EAST       Urban  ...  RIFT VALLEY  Trans Nzoia
#
# [5 rows x 21 columns]

# %%
#Preview the first 10 rows the remaining columns in our data set
#
sanitation_by_district.head(10)
# Out:
#           _District Rural/Urban  ...     Province       County
# 0           MOMBASA       Rural  ...        COAST      Mombasa
# 1            CHALBI       Urban  ...      EASTERN     Marsabit
# 2        KURIA EAST       Urban  ...       NYANZA       Migori
# 3             MANGA       Rural  ...       NYANZA      Nyamira
# 4  TRANS NZOIA EAST       Urban  ...  RIFT VALLEY  Trans Nzoia
# 5       NANDI SOUTH       Urban  ...  RIFT VALLEY        Nandi
# 6            HAMISI       Urban  ...      WESTERN       Vihiga
# 7   NYANDARUA NORTH       Urban  ...      CENTRAL    Nyandarua
# 8   NYANDARUA SOUTH       Urban  ...      CENTRAL    Nyandarua
# 9       NYERI NORTH       Urban  ...      CENTRAL        Nyeri
#
# [10 rows x 21 columns]

# %%
#resetting index
#
sanitation_by_district.reset_index(drop=True)

sanitation_by_district.head(5)
# Out:
#           _District Rural/Urban  ...     Province       County
# 0           MOMBASA       Rural  ...        COAST      Mombasa
# 1            CHALBI       Urban  ...      EASTERN     Marsabit
# 2        KURIA EAST       Urban  ...       NYANZA       Migori
# 3             MANGA       Rural  ...       NYANZA      Nyamira
# 4  TRANS NZOIA EAST       Urban  ...  RIFT VALLEY  Trans Nzoia
#
# [5 rows x 21 columns]

# %%
#clearing any white space in the columns data
# 
sanitation_by_district.columns = sanitation_by_district.columns.str.strip()

sanitation_by_district
# Out:
#             _District Rural/Urban  ...     Province       County
# 0             MOMBASA       Rural  ...        COAST      Mombasa
# 1              CHALBI       Urban  ...      EASTERN     Marsabit
# 2          KURIA EAST       Urban  ...       NYANZA       Migori
# 3               MANGA       Rural  ...       NYANZA      Nyamira
# 4    TRANS NZOIA EAST       Urban  ...  RIFT VALLEY  Trans Nzoia
# ..                ...         ...  ...          ...          ...
# 311             BUSIA       Rural  ...      WESTERN        Busia
# 312        TESO NORTH       Rural  ...      WESTERN        Busia
# 313             SAMIA       Rural  ...      WESTERN        Busia
# 314           BUNYALA       Rural  ...      WESTERN        Busia
# 315        TESO SOUTH       Rural  ...      WESTERN        Busia
#
# [316 rows x 21 columns]

# %% [markdown]
# Completeness of data.

# %%
#checking for the existence of any null values 
#
sanitation_by_district.isnull().values.any()
# Out:
# True

# %%
#Dropping the rows with null values
#
sanitation_by_district_1 = sanitation_by_district.dropna()
 
sanitation_by_district_1
# Out:
#            _District Rural/Urban  ... Province     County
# 3              MANGA       Rural  ...   NYANZA    Nyamira
# 7    NYANDARUA NORTH       Urban  ...  CENTRAL  Nyandarua
# 8    NYANDARUA SOUTH       Urban  ...  CENTRAL  Nyandarua
# 9        NYERI NORTH       Urban  ...  CENTRAL      Nyeri
# 10       NYERI SOUTH       Urban  ...  CENTRAL      Nyeri
# ..               ...         ...  ...      ...        ...
# 311            BUSIA       Rural  ...  WESTERN      Busia
# 312       TESO NORTH       Rural  ...  WESTERN      Busia
# 313            SAMIA       Rural  ...  WESTERN      Busia
# 314          BUNYALA       Rural  ...  WESTERN      Busia
# 315       TESO SOUTH       Rural  ...  WESTERN      Busia
#
# [290 rows x 21 columns]

# %%
#resetting index
#
sanitation_by_district_1.reset_index(inplace=True)

# %%
#previewing dataset 
#
sanitation_by_district_1.head(5)
# Out:
#    index        _District  ... Province     County
# 0      3            MANGA  ...   NYANZA    Nyamira
# 1      7  NYANDARUA NORTH  ...  CENTRAL  Nyandarua
# 2      8  NYANDARUA SOUTH  ...  CENTRAL  Nyandarua
# 3      9      NYERI NORTH  ...  CENTRAL      Nyeri
# 4     10      NYERI SOUTH  ...  CENTRAL      Nyeri
#
# [5 rows x 22 columns]

# %%
#dropping irrelevant column
#
sanitation_by_district_1.pop('index')
sanitation_by_district_1
# Out:
#            _District Rural/Urban  ... Province     County
# 0              MANGA       Rural  ...   NYANZA    Nyamira
# 1    NYANDARUA NORTH       Urban  ...  CENTRAL  Nyandarua
# 2    NYANDARUA SOUTH       Urban  ...  CENTRAL  Nyandarua
# 3        NYERI NORTH       Urban  ...  CENTRAL      Nyeri
# 4        NYERI SOUTH       Urban  ...  CENTRAL      Nyeri
# ..               ...         ...  ...      ...        ...
# 285            BUSIA       Rural  ...  WESTERN      Busia
# 286       TESO NORTH       Rural  ...  WESTERN      Busia
# 287            SAMIA       Rural  ...  WESTERN      Busia
# 288          BUNYALA       Rural  ...  WESTERN      Busia
# 289       TESO SOUTH       Rural  ...  WESTERN      Busia
#
# [290 rows x 21 columns]

# %% [markdown]
# Consistency of data.

# %%
#checking if there is any existence of duplicates in the data file
#And dropping if any exists 
#
sanitation_by_district_1.duplicated().values.any()
# Out:
# False

# %%
# There are no duplicates in the file

# %% [markdown]
# Uniformity of data.

# %%
#fix column names and turn them to lower case
#remove the white space in between the names 
#
sanitation_by_district_1.columns = sanitation_by_district_1.columns.str.replace(' ','_').str.lower()
sanitation_by_district_1=sanitation_by_district_1.rename(columns={'_district':'district'})

sanitation_by_district_1.head(5)
# Out:
#           district rural/urban  ... province     county
# 0            MANGA       Rural  ...   NYANZA    Nyamira
# 1  NYANDARUA NORTH       Urban  ...  CENTRAL  Nyandarua
# 2  NYANDARUA SOUTH       Urban  ...  CENTRAL  Nyandarua
# 3      NYERI NORTH       Urban  ...  CENTRAL      Nyeri
# 4      NYERI SOUTH       Urban  ...  CENTRAL      Nyeri
#
# [5 rows x 21 columns]

# %% [markdown]
# **2.2.IMPORTING CLEANED DATASET.**

# %%
#
sanitation_by_district_1.to_csv('sanitation_by_district_1')
 
sanitation_by_district_1.head()
# Out:
#           district rural/urban  ... province     county
# 0            MANGA       Rural  ...   NYANZA    Nyamira
# 1  NYANDARUA NORTH       Urban  ...  CENTRAL  Nyandarua
# 2  NYANDARUA SOUTH       Urban  ...  CENTRAL  Nyandarua
# 3      NYERI NORTH       Urban  ...  CENTRAL      Nyeri
# 4      NYERI SOUTH       Urban  ...  CENTRAL      Nyeri
#
# [5 rows x 21 columns]

# %%
#Loading the new dataset and resetting the index values 
#
Sanitation_in_Kenya = pd.read_csv('sanitation_by_district_1')
Sanitation_in_Kenya.head(5)
 
Sanitation_in_Kenya.reset_index(inplace=True)
Sanitation_in_Kenya.head(5)

Sanitation_in_Kenya.drop(['index','Unnamed: 0'], axis = 1, inplace = True)
Sanitation_in_Kenya
# Out:
#             district rural/urban  ... province     county
# 0              MANGA       Rural  ...   NYANZA    Nyamira
# 1    NYANDARUA NORTH       Urban  ...  CENTRAL  Nyandarua
# 2    NYANDARUA SOUTH       Urban  ...  CENTRAL  Nyandarua
# 3        NYERI NORTH       Urban  ...  CENTRAL      Nyeri
# 4        NYERI SOUTH       Urban  ...  CENTRAL      Nyeri
# ..               ...         ...  ...      ...        ...
# 285            BUSIA       Rural  ...  WESTERN      Busia
# 286       TESO NORTH       Rural  ...  WESTERN      Busia
# 287            SAMIA       Rural  ...  WESTERN      Busia
# 288          BUNYALA       Rural  ...  WESTERN      Busia
# 289       TESO SOUTH       Rural  ...  WESTERN      Busia
#
# [290 rows x 21 columns]

# %% [markdown]
# ## **Analysis**

# %%
#Finding the most popular and least popular form of Sanitation across the country

#First combining the different columns on sanitation categories into one list
Household_Sanitation_Categories = ["no_of_households_with_main_sewer", "no_of_households_with_septic_tank",
                                    "no_of_households_with_cess_pool", "no_of_households_with_vip_pit_latrine",
                                    "no_of_households_with_pit_latrine_covered/uncovered", 
                                    "no_of_households_with_bucket",	"no_of_households_with_bush", 
                                    "no_of_households_with_other"]

#Determining the popularity of the different forms of sanitation in descending order

Popular = Sanitation_in_Kenya[Household_Sanitation_Categories].sum().sort_values(ascending=False)
Popular

#From the order we can determine the most and least popular form of sanitation
# Out:
# no_of_households_with_pit_latrine_covered/uncovered    6100234
# no_of_households_with_bush                             1196509
# no_of_households_with_main_sewer                        674541
# no_of_households_with_vip_pit_latrine                   430827
# no_of_households_with_septic_tank                       299030
# no_of_households_with_cess_pool                          29881
# no_of_households_with_bucket                             22828
# no_of_households_with_other                              14104
# dtype: int64

# %%
## A bar graph to show the differences in least and most popular forms of sanitation
# in the country

Popular.plot.bar( )

# %%
# Different forms of sanitation in the country ordered by percentage

(Sanitation_in_Kenya[Household_Sanitation_Categories].sum()/Sanitation_in_Kenya.households.sum()*100).sort_values(ascending=False)
# Out:
# no_of_households_with_pit_latrine_covered/uncovered    69.574202
# no_of_households_with_bush                             13.646388
# no_of_households_with_main_sewer                        7.693254
# no_of_households_with_vip_pit_latrine                   4.913655
# no_of_households_with_septic_tank                       3.410488
# no_of_households_with_cess_pool                         0.340798
# no_of_households_with_bucket                            0.260357
# no_of_households_with_other                             0.160859
# dtype: float64

# %%
# Determining total number of households in urban areas
urban = Sanitation_in_Kenya.loc[Sanitation_in_Kenya['rural/urban'] == 'Urban' ]
urban

total_urban = urban['households'].sum()
total_urban
# Out:
# 3406620

# %%
# Determining total number of households in rural areas
rural = Sanitation_in_Kenya.loc[Sanitation_in_Kenya['rural/urban'] == 'Rural' ]
rural

total_rural = rural['households'].sum()
total_rural
# Out:
# 5361334

# %%
# Different forms of sanitation in urban areas ordered by percentage

urban_category_proportion = ((urban[Household_Sanitation_Categories].sum())/total_urban * 100).sort_values(ascending = False)
urban_category_proportion
# Out:
# no_of_households_with_pit_latrine_covered/uncovered    62.502422
# no_of_households_with_main_sewer                       19.511216
# no_of_households_with_septic_tank                       8.028486
# no_of_households_with_vip_pit_latrine                   5.923878
# no_of_households_with_bush                              2.556023
# no_of_households_with_cess_pool                         0.734570
# no_of_households_with_bucket                            0.553833
# no_of_households_with_other                             0.189572
# dtype: float64

# %%
#Creating a bar graph of the different sanitation category percentanges in urban areas

urban_category_proportion.plot.bar()

# %%
# Different forms of sanitation in rural areas ordered by percentage

rural_category_proportion = ((rural[Household_Sanitation_Categories].sum())/total_rural * 100).sort_values(ascending = False)
rural_category_proportion
# Out:
# no_of_households_with_pit_latrine_covered/uncovered    74.067648
# no_of_households_with_bush                             20.693264
# no_of_households_with_vip_pit_latrine                   4.271754
# no_of_households_with_septic_tank                       0.476187
# no_of_households_with_main_sewer                        0.184059
# no_of_households_with_other                             0.142614
# no_of_households_with_cess_pool                         0.090593
# no_of_households_with_bucket                            0.073881
# dtype: float64

# %%
#Creating a bar graph of the different sanitation category percentanges in rural areas

rural_category_proportion.plot.bar()

# %%
#Determining the most and least popular form of sanitation per county

#First creating a dataframe to reflect the county and different sanitation categories

Household_Sanitation_Categories_county = Sanitation_in_Kenya[['county',"no_of_households_with_main_sewer", "no_of_households_with_septic_tank",
                                                "no_of_households_with_cess_pool", "no_of_households_with_vip_pit_latrine",
                                                "no_of_households_with_pit_latrine_covered/uncovered", 
                                                "no_of_households_with_bucket",	"no_of_households_with_bush", 
                                                "no_of_households_with_other"]]
Household_Sanitation_Categories_county

#Finding the sum of each category per county(grouped by county)

Sum = Household_Sanitation_Categories_county.groupby('county').sum()
Sum.head()

#The most popular and least popular forms of sanitation per county determined in the next cells
# Out:
#                  no_of_households_with_main_sewer  ...  no_of_households_with_other
# county                                             ...
# Baringo                                       296  ...                           59
# Bomet                                         565  ...                          113
# Bungoma                                      1936  ...                          743
# Busia                                         545  ...                          223
# Elgeyo Marakwet                               295  ...                           34
#
# [5 rows x 8 columns]

# %%
#Finding the least popular form of sanitation per county 

Sum.idxmin(axis=1)
# Out:
# county
# Baringo                 no_of_households_with_bucket
# Bomet                   no_of_households_with_bucket
# Bungoma              no_of_households_with_cess_pool
# Busia                   no_of_households_with_bucket
# Elgeyo Marakwet      no_of_households_with_cess_pool
# Embu                    no_of_households_with_bucket
# Garissa              no_of_households_with_cess_pool
# Homa Bay             no_of_households_with_cess_pool
# Isiolo               no_of_households_with_cess_pool
# Kajiado                 no_of_households_with_bucket
# Kakamega                no_of_households_with_bucket
# Kericho                  no_of_households_with_other
# Kiambu                   no_of_households_with_other
# Kilifi                   no_of_households_with_other
# Kirinyaga                no_of_households_with_other
# Kisii                   no_of_households_with_bucket
# Kisumu                  no_of_households_with_bucket
# Kitui                   no_of_households_with_bucket
# Kwale                    no_of_households_with_other
# Laikipia                 no_of_households_with_other
# Lamu                no_of_households_with_main_sewer
# Machakos                no_of_households_with_bucket
# Makueni                  no_of_households_with_other
# Mandera            no_of_households_with_septic_tank
# Marsabit            no_of_households_with_main_sewer
# Meru                    no_of_households_with_bucket
# Migori               no_of_households_with_cess_pool
# Mombasa                  no_of_households_with_other
# Murang'a                 no_of_households_with_other
# Nairobi                  no_of_households_with_other
# Nakuru                   no_of_households_with_other
# Nandi                   no_of_households_with_bucket
# Narok                no_of_households_with_cess_pool
# Nyamira                  no_of_households_with_other
# Nyandarua                no_of_households_with_other
# Nyeri                    no_of_households_with_other
# Samburu                 no_of_households_with_bucket
# Siaya                   no_of_households_with_bucket
# Taita Taveta            no_of_households_with_bucket
# Tana River           no_of_households_with_cess_pool
# Tharaka Nithi           no_of_households_with_bucket
# Trans Nzoia             no_of_households_with_bucket
# Turkana                 no_of_households_with_bucket
# Uasin Gishu             no_of_households_with_bucket
# Vihiga                  no_of_households_with_bucket
# Wajir                no_of_households_with_cess_pool
# West Pokot              no_of_households_with_bucket
# dtype: object

# %%
#Finding the most popular form of sanitation per county

Sum.idxmax(axis=1)
# Out:
# county
# Baringo            no_of_households_with_pit_latrine_covered/unco...
# Bomet              no_of_households_with_pit_latrine_covered/unco...
# Bungoma            no_of_households_with_pit_latrine_covered/unco...
# Busia              no_of_households_with_pit_latrine_covered/unco...
# Elgeyo Marakwet    no_of_households_with_pit_latrine_covered/unco...
# Embu               no_of_households_with_pit_latrine_covered/unco...
# Garissa                                   no_of_households_with_bush
# Homa Bay           no_of_households_with_pit_latrine_covered/unco...
# Isiolo             no_of_households_with_pit_latrine_covered/unco...
# Kajiado            no_of_households_with_pit_latrine_covered/unco...
# Kakamega           no_of_households_with_pit_latrine_covered/unco...
# Kericho            no_of_households_with_pit_latrine_covered/unco...
# Kiambu             no_of_households_with_pit_latrine_covered/unco...
# Kilifi             no_of_households_with_pit_latrine_covered/unco...
# Kirinyaga          no_of_households_with_pit_latrine_covered/unco...
# Kisii              no_of_households_with_pit_latrine_covered/unco...
# Kisumu             no_of_households_with_pit_latrine_covered/unco...
# Kitui              no_of_households_with_pit_latrine_covered/unco...
# Kwale                                     no_of_households_with_bush
# Laikipia           no_of_households_with_pit_latrine_covered/unco...
# Lamu               no_of_households_with_pit_latrine_covered/unco...
# Machakos           no_of_households_with_pit_latrine_covered/unco...
# Makueni            no_of_households_with_pit_latrine_covered/unco...
# Mandera                                   no_of_households_with_bush
# Marsabit                                  no_of_households_with_bush
# Meru               no_of_households_with_pit_latrine_covered/unco...
# Migori             no_of_households_with_pit_latrine_covered/unco...
# Mombasa            no_of_households_with_pit_latrine_covered/unco...
# Murang'a           no_of_households_with_pit_latrine_covered/unco...
# Nairobi                             no_of_households_with_main_sewer
# Nakuru             no_of_households_with_pit_latrine_covered/unco...
# Nandi              no_of_households_with_pit_latrine_covered/unco...
# Narok                                     no_of_households_with_bush
# Nyamira            no_of_households_with_pit_latrine_covered/unco...
# Nyandarua          no_of_households_with_pit_latrine_covered/unco...
# Nyeri              no_of_households_with_pit_latrine_covered/unco...
# Samburu                                   no_of_households_with_bush
# Siaya              no_of_households_with_pit_latrine_covered/unco...
# Taita Taveta       no_of_households_with_pit_latrine_covered/unco...
# Tana River                                no_of_households_with_bush
# Tharaka Nithi      no_of_households_with_pit_latrine_covered/unco...
# Trans Nzoia        no_of_households_with_pit_latrine_covered/unco...
# Turkana                                   no_of_households_with_bush
# Uasin Gishu        no_of_households_with_pit_latrine_covered/unco...
# Vihiga             no_of_households_with_pit_latrine_covered/unco...
# Wajir                                     no_of_households_with_bush
# West Pokot                                no_of_households_with_bush
# dtype: object

# %%
#Finding the top ten districts with highest number of households using bushes

Top_ten_districts_bush = Sanitation_in_Kenya[['district','no_of_households_with_bush']].sort_values('no_of_households_with_bush',ascending=False).head(10)
Top_ten_districts_bush
# Out:
#             district  no_of_households_with_bush
# 210    TURKANA NORTH                       38517
# 243      NAROK SOUTH                       35464
# 132  MANDERA CENTRAL                       33895
# 160          HOMABAY                       33210
# 163           MIGORI                       31017
# 209  TURKANA CENTRAL                       29802
# 51           MALINDI                       29477
# 161             SUBA                       25308
# 134     MANDERA WEST                       25141
# 47           KINANGO                       24953

# %%
#Finding the top 10 counties with the highest number of households using bushes

Top_ten_county_bush = Sanitation_in_Kenya.groupby(['county']).no_of_households_with_bush.sum().sort_values(ascending=False).head(10)
Top_ten_county_bush
# Out:
# county
# Turkana       100997
# Mandera        82437
# Narok          81700
# Homa Bay       79509
# Wajir          67723
# Kilifi         67545
# Kitui          63204
# West Pokot     62901
# Kwale          62342
# Migori         59404
# Name: no_of_households_with_bush, dtype: int64

# %%
#Finding whether the top ten districts with highest number of households are in 
#the top ten counties with largest number of households using bushes

#First finding which counties the districts belong to and output displayed below

for ind in Top_ten_districts_bush.index:
  A = Sanitation_in_Kenya['district'][ind]
  B = Sanitation_in_Kenya['county'][ind]
  print(A,'-',B)

#Checking whether these counties are part of the ones displayed in top 10
#as the counties with highest number of households using bushes and we find it is the case as displayed below as 'True'

if B in Top_ten_county_bush:
  print("True")
else:
  print("False")
# Out:
# TURKANA NORTH - Turkana
# NAROK SOUTH - Narok
# MANDERA CENTRAL - Mandera
# HOMABAY - Homa Bay
# MIGORI - Migori
# TURKANA CENTRAL - Turkana
# MALINDI - Kilifi
# SUBA - Homa Bay
# MANDERA WEST - Mandera
# KINANGO - Kwale
# True

# %%
#Determine the top 10 districts with highest and number of households using buckets

Top_ten_districts_bucket = Sanitation_in_Kenya[['district','no_of_households_with_bucket']].sort_values('no_of_households_with_bucket',ascending=False).head(10)
Top_ten_districts_bucket
# Out:
#           district  no_of_households_with_bucket
# 119     WAJIR EAST                          6534
# 112  NAIROBI NORTH                          2053
# 111   NAIROBI EAST                          1689
# 33         MOMBASA                          1645
# 34       KILINDINI                          1395
# 110   NAIROBI WEST                          1353
# 38          KILIFI                           456
# 40         MALINDI                           393
# 195         NAKURU                           285
# 21       KIRINYAGA                           208

# %%
#Finding the top 10 counties with the highest number of households using buckets

Top_ten_county_bucket = Sanitation_in_Kenya.groupby(['county']).no_of_households_with_bucket.sum().sort_values(ascending=False).head(10)
Top_ten_county_bucket
# Out:
# county
# Wajir       6660
# Nairobi     5205
# Mombasa     3040
# Kilifi      1152
# Nakuru       554
# Kiambu       491
# Kakamega     336
# Garissa      308
# Machakos     307
# Bungoma      303
# Name: no_of_households_with_bucket, dtype: int64

# %%
#Finding whether the top ten districts with highest number of households are in 
#the top ten counties with largest number of households using buckets

#First finding which counties the districts belong to and output displayed below

for ind in Top_ten_districts_bucket.index:
  A = Sanitation_in_Kenya['district'][ind]
  B = Sanitation_in_Kenya['county'][ind]
  print(A,'-',B)

#Checking whether these counties are part of the ones displayed in top 10
#as the counties with highest number of households using buckets and we find it is the case as displayed below as 'False'

if B in Top_ten_county_bucket:
  print("True")
else:
  print("False")

#Kirinyaga county is not part of the top ten counties with highest number of counties using bushes
#but one of its districts is in Top ten districts with highest number of households using buckets
# Out:
# WAJIR EAST - Wajir
# NAIROBI NORTH - Nairobi
# NAIROBI EAST - Nairobi
# MOMBASA - Mombasa
# KILINDINI - Mombasa
# NAIROBI WEST - Nairobi
# KILIFI - Kilifi
# MALINDI - Kilifi
# NAKURU - Nakuru
# KIRINYAGA - Kirinyaga
# False

# %%
#Finding counties with highest and lowest number of households connected to main sewer

Sanitation_in_Kenya.groupby(['county']).no_of_households_with_main_sewer.sum().sort_values(ascending=False)
# Out:
# county
# Nairobi            469830
# Mombasa             37225
# Nakuru              32864
# Kiambu              31288
# Uasin Gishu         16411
# Machakos            11666
# Kisumu              10933
# Laikipia            10324
# Nyeri                9633
# Kakamega             5272
# Murang'a             3967
# Embu                 3264
# Kilifi               3234
# Trans Nzoia          2802
# Kericho              2695
# Kajiado              2407
# Meru                 2306
# Bungoma              1936
# Homa Bay             1869
# Kisii                1640
# Isiolo               1557
# Kirinyaga            1222
# Garissa              1121
# Makueni              1032
# Taita Taveta          953
# Migori                861
# Narok                 755
# Kwale                 614
# Nandi                 599
# Bomet                 565
# Busia                 545
# Kitui                 433
# Siaya                 396
# Vihiga                374
# Nyandarua             346
# Baringo               296
# Elgeyo Marakwet       295
# Turkana               192
# Wajir                 151
# West Pokot            132
# Tana River            132
# Mandera               122
# Samburu                94
# Lamu                   75
# Nyamira                72
# Marsabit               22
# Tharaka Nithi          19
# Name: no_of_households_with_main_sewer, dtype: int64

# %%
#Finding districts in urban areas with highest number of households connected to main sewer

urban[['district','rural/urban','no_of_households_with_main_sewer']].sort_values('no_of_households_with_main_sewer',ascending=False).head()
# Out:
#           district rural/urban  no_of_households_with_main_sewer
# 111   NAIROBI EAST       Urban                            214428
# 112  NAIROBI NORTH       Urban                            182521
# 110   NAIROBI WEST       Urban                             41426
# 113      WESTLANDS       Urban                             31455
# 195         NAKURU       Urban                             24770

# %%
#Finding counties in urban areas with highest and lowest number of households connected to main sewer

urban.groupby('county').no_of_households_with_main_sewer.sum().sort_values(ascending=False)
# Out:
# county
# Nairobi            469830
# Mombasa             37225
# Nakuru              32206
# Kiambu              30572
# Uasin Gishu         16116
# Machakos            11549
# Kisumu              10797
# Laikipia            10211
# Nyeri                8998
# Kakamega             4797
# Murang'a             3402
# Kilifi               2755
# Trans Nzoia          2699
# Embu                 2687
# Kericho              2612
# Kajiado              2090
# Meru                 1766
# Bungoma              1723
# Homa Bay             1659
# Isiolo               1516
# Kisii                1512
# Kirinyaga             981
# Garissa               973
# Migori                782
# Makueni               767
# Taita Taveta          696
# Nandi                 502
# Busia                 490
# Kwale                 433
# Kitui                 313
# Vihiga                276
# Baringo               238
# Nyandarua             234
# Siaya                 222
# Bomet                 220
# Narok                 180
# Wajir                 120
# Elgeyo Marakwet       108
# Mandera                81
# Samburu                77
# Tana River             63
# Turkana                62
# Lamu                   57
# Nyamira                36
# West Pokot             31
# Marsabit                7
# Tharaka Nithi           2
# Name: no_of_households_with_main_sewer, dtype: int64

# %%
# Determining percentage of urban households connected to the main sewers

(urban['no_of_households_with_main_sewer'].sum()/total_urban) * 100
# Out:
# 19.51121639631071

# %%
#Finding districts in rural areas with highest number of households connected to main sewer

rural[['district','rural/urban','no_of_households_with_main_sewer']].sort_values('no_of_households_with_main_sewer',ascending=False).head()
# Out:
#           district rural/urban  no_of_households_with_main_sewer
# 19     NYERI NORTH       Rural                               427
# 241           MOLO       Rural                               370
# 243    NAROK SOUTH       Rural                               344
# 98          MBEERE       Rural                               314
# 22   MURANGA NORTH       Rural                               270

# %%
#Finding counties in rural areas with highest and lowest number of households connected to main sewer

rural.groupby('county').no_of_households_with_main_sewer.sum().sort_values(ascending=False)
# Out:
# county
# Kiambu             716
# Nakuru             658
# Nyeri              635
# Embu               577
# Narok              575
# Murang'a           565
# Meru               540
# Kilifi             479
# Kakamega           475
# Bomet              345
# Kajiado            317
# Uasin Gishu        295
# Makueni            265
# Taita Taveta       257
# Kirinyaga          241
# Bungoma            213
# Homa Bay           210
# Elgeyo Marakwet    187
# Kwale              181
# Siaya              174
# Garissa            148
# Kisumu             136
# Turkana            130
# Kisii              128
# Kitui              120
# Machakos           117
# Laikipia           113
# Nyandarua          112
# Trans Nzoia        103
# West Pokot         101
# Vihiga              98
# Nandi               97
# Kericho             83
# Migori              79
# Tana River          69
# Baringo             58
# Busia               55
# Mandera             41
# Isiolo              41
# Nyamira             36
# Wajir               31
# Lamu                18
# Samburu             17
# Tharaka Nithi       17
# Marsabit            15
# Name: no_of_households_with_main_sewer, dtype: int64
